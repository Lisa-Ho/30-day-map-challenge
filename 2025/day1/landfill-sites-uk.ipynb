# %% [markdown]
# ## Day 1: Points
#
# Landfill sites in the UK

# %%
#setup
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob
import os

# %%
#load geojson
gdf = gpd.read_file("Permitted_Waste_Sites_Authorised_Landfill_Site_Boundaries.geojson")

# %%
#load data sets
folder_path = os.getcwd()
excel_files = glob.glob(os.path.join(folder_path, '*.xlsx'))
years = np.arange(2015, 2025, 1)
rows_to_ignore = [ 17, 7, 7, 7, 7, 7, 9 , 8, 7, 7 ]
dataframes = []

#loop through each file, clean up and combine at the end 
for i, file in enumerate(excel_files):
    frame = pd.read_excel(file, skiprows=rows_to_ignore[i])
    frame["Year"] = years[i]
    if years[i] < 2023:
        frame["Environmental Permitting Reference (EPR)"] = None
        cols = frame.columns.tolist()
        new_order = [cols[-1]] + cols[:-1]
        frame = frame[new_order]
    frame.columns = ["epr", "legacy_permit", "operator_name", "facility_name", "facility_address", "ea_area",
                  "region", "sub_region", "local_authority", "site_type", "remaining_capacity", "year", ]
    dataframes.append(frame)

df = pd.concat(dataframes, ignore_index=True)

#fix incorrect legacy permit code
df.loc[(df["operator_name"]=="Cory Environmental (Gloucestershire)Limited") &
   (df["legacy_permit"]=="TP3735PA"), "legacy_permit"] = "NP3736DS"

df["postcodes"] = df["facility_address"].str.replace(",", "").str[-8:].str.strip()


df
# Out:
#            epr legacy_permit                           operator_name  \
# 0         None         10264                      HH AND DE Drew Ltd
# 1         None         10285              Westridge Developments Ltd
# 2         None         19737           Inert Waste Recycling Limited
# 3         None         21785                         Leese's Limited
# 4         None         23517           Harley                   Jack
# ...        ...           ...                                     ...
# 5257  ZP3533GG      ZP3533GG                    Margetts Pit Limited
# 5258  ZP3606BG      ZP3606BG                   British Steel Limited
# 5259  ZP3832SQ        210109                 Cemex U K Materials Ltd
# 5260  ZP3835JD        406424  Escrick Environmental Services Limited
# 5261  ZP3933LD      ZP3933LD           Severn Waste Services Limited
#
#                             facility_name  \
# 0                     Lower Farm Landfill
# 1                       Lynn Pit Landfill
# 2                       Boxgrove Landfill
# 3                   Kenbury Wood Landfill
# 4     Chitterne Waste Management Facility
# ...                                   ...
# 5257          Margetts Pit SNRHW Landfill
# 5258                Crosby North Landfill
# 5259              Great Westwood Landfill
# 5260           Escrick Soil Landfill Site
# 5261               Hill and Moor Landfill
#
#                                        facility_address  \
# 0     Lower Farm, Lower Pennington, New Milton SO41 8DF
# 1                  Briddlesford Road, Down End PO30 2PD
# 2     Tinwood Lane, Eartham, Chichester, West Sussex...
# 3                       Kenbury Wood, Exminster EX6 7XD
# 4     Valley Farm,  Chitterne, Warminster, Wiltshire...
# ...                                                 ...
# 5257     Margetts Lane, Burham, Rochester, Kent ME1 3RQ
# 5258                              Daws Lane, Scunthorpe
# 5259  Great Westwood Landfill,  Fir Tree Hill, Chand...
# 5260  Escrick Environmental Services Ltd,  The Old B...
# 5261         Throckmorton, Pershore, Worcester WR10 2PW
#
#                      ea_area                   region         sub_region  \
# 0     Solent and South Downs               South East          Hampshire
# 1     Solent and South Downs               South East      Isle of Wight
# 2       Solent & South Downs               South East        West Sussex
# 3           Devon & Cornwall               South West              Devon
# 4                     Wessex               South West          Wiltshire
# ...                      ...                      ...                ...
# 5257   Kent and South London              South East                Kent
# 5258           East Midlands  Yorkshire & the Humber   Former Humberside
# 5259  Herts and North London          East of England      Hertfordshire
# 5260               Yorkshire  Yorkshire & the Humber     North Yorkshire
# 5261           West Midlands           West Midlands      Worcestershire
#
#             local_authority                                     site_type  \
# 0                New Forest                                Inert Landfill
# 1             Isle of Wight                                Inert Landfill
# 2                Chichester                                Inert Landfill
# 3               Teignbridge                                Inert Landfill
# 4                 Wiltshire                                Inert Landfill
# ...                     ...                                           ...
# 5257  Tonbridge and Malling  L02 - Non Hazardous Landfill With SNRHW cell
# 5258     North Lincolnshire                           L04 - Non Hazardous
# 5259           Three Rivers                          L05 - Inert Landfill
# 5260        North Yorkshire                          L05 - Inert Landfill
# 5261               Wychavon                           L04 - Non Hazardous
#
#      remaining_capacity  year postcodes
# 0                Closed  2015  SO41 8DF
# 1                Closed  2015  PO30 2PD
# 2                640000  2015  PO18 0NB
# 3                512022  2015   EX6 7XD
# 4                     0  2015  BA12 0LT
# ...                 ...   ...       ...
# 5257                  0  2024   ME1 3RQ
# 5258            1641301  2024  unthorpe
# 5259                  0  2024   WD3 4LY
# 5260             428521  2024  YO19 6ED
# 5261            1455487  2024  WR10 2PW
#
# [5262 rows x 13 columns]

# %% [markdown]
# ## Exploration

# %%
df[df["epr"]=="BJ6003IF"]
# Out:
#            epr legacy_permit               operator_name  \
# 4213  BJ6003IF      BJ6003IF  Veolia ES Landfill Limited
# 4748  BJ6003IF      BJ6003IF  Veolia ES Landfill Limited
#
#                  facility_name  \
# 4213  New Albion Landfill Site
# 4748  New Albion Landfill Site
#
#                                        facility_address        ea_area  \
# 4213  Occupation Road, Spring Cottage, Albert Villag...  West Midlands
# 4748  Occupation Road, Spring Cottage, Albert Villag...  West Midlands
#
#              region      sub_region            local_authority  \
# 4213  East Midlands  Leicestershire  North West Leicestershire
# 4748  East Midlands  Leicestershire  North West Leicestershire
#
#                 site_type remaining_capacity  year
# 4213  L04 - Non Hazardous                  0  2023
# 4748  L04 - Non Hazardous                  0  2024

# %%
#Scope of data
permit_counts = df['legacy_permit'].value_counts().reset_index()
frequent_permits = permit_counts[permit_counts["count"] > 9]
print("N of providers in 10 files:", len(frequent_permits))

print("Unique epr codes:", df["epr"].nunique())
print("Unique legacy codes:", df["legacy_permit"].nunique())
print("Unique operator names:", df["operator_name"].nunique())
print("Unique facility names:", df["facility_name"].nunique())
# Out:
# N of providers in 10 files: 422
# Unique epr codes: 540
# Unique legacy codes: 629
# Unique operator names: 534
# Unique facility names: 741

# %%
uk_postcode_pattern = r'^[A-Z]{1,2}\d{1,2}[A-Z]?\s?\d[A-Z]{2}$'
invalid_df = df[~df['postcodes'].str.upper().str.match(uk_postcode_pattern, na=False)]
invalid_df["postcodes"].tolist()
# Out:
# ['edbridge',
#  'ow Essex',
#  'r Surrey',
#  'W 18 4JX',
#  'Rutland',
#  nan,
#  'zard LU7',
#  nan,
#  'yldesley',
#  'nemouth',
#  'DN6  7EX',
#  'y S9 1LH',
#  'CW 15NG',
#  'd S3 8AG',
#  'd S9 1TR',
#  'LS27 OJA',
#  'unthorpe',
#  'ersfield',
#  'heshire',
#  nan,
#  'nemouth',
#  'LS27 OJA',
#  'unthorpe',
#  'ow Essex',
#  'edbridge',
#  'DN6  7EX',
#  'W 18 4JX',
#  'y S9 1LH',
#  'heshire',
#  'ersfield',
#  'r Surrey',
#  'CW 15NG',
#  'yldesley',
#  'd S3 8AG',
#  nan,
#  'zard LU7',
#  'd S9 1TR',
#  'Rutland',
#  'edbridge',
#  'W 18 4JX',
#  'Rutland',
#  nan,
#  'zard LU7',
#  'ank Lydd',
#  'yldesley',
#  'nemouth',
#  'DN6  7EX',
#  'y S9 1LH',
#  'CW 15NG',
#  'd S3 8AG',
#  'd S9 1TR',
#  'unthorpe',
#  'LS27 OJA',
#  'ersfield',
#  'heshire',
#  'heshire',
#  'unthorpe',
#  'ank Lydd',
#  'nemouth',
#  'yldesley',
#  nan,
#  'Rutland',
#  'd S9 1TR',
#  'CW 15NG',
#  nan,
#  'LS27 OJA',
#  'DN6  7EX',
#  'edbridge',
#  'W 18 4JX',
#  'zard LU7',
#  'y S9 1LH',
#  'd S3 8AG',
#  'ersfield',
#  nan,
#  'edbridge',
#  'W 18 4JX',
#  'Rutland',
#  nan,
#  'zard LU7',
#  'ank Lydd',
#  'yldesley',
#  'nemouth',
#  'DN6  7EX',
#  'y S9 1LH',
#  'CW 15NG',
#  'd S3 8AG',
#  'd S9 1TR',
#  'unthorpe',
#  'LS27 OJA',
#  'ersfield',
#  'heshire',
#  nan,
#  'edbridge',
#  'W 18 4JX',
#  'Rutland',
#  nan,
#  'zard LU7',
#  'ank Lydd',
#  'yldesley',
#  'nemouth',
#  'DN6  7EX',
#  'y S9 1LH',
#  'CW 15NG',
#  'd S3 8AG',
#  'd S9 1TR',
#  'unthorpe',
#  'ersfield',
#  'LS27 OJA',
#  'heshire',
#  'ampshire',
#  'ordshire',
#  'DN6  7EX',
#  'y S9 1LH',
#  'CW 15NG',
#  'd S3 8AG',
#  'd S9 1TR',
#  'ersfield',
#  'LS27 OJA',
#  'heshire',
#  'unthorpe',
#  'ordshire',
#  'unthorpe',
#  'd S9 1TR',
#  'DN6  7EX',
#  'y S9 1LH',
#  'ampshire',
#  'heshire',
#  'CW 15NG',
#  'ersfield',
#  'd S3 8AG',
#  'LS27 OJA',
#  'DN6  7EX',
#  'y S9 1LH',
#  'CW 15NG',
#  'd S3 8AG',
#  'ersfield',
#  'ampshire',
#  'ordshire',
#  'LS27 OJA',
#  'd S9 1TR',
#  'heshire',
#  'unthorpe',
#  'DN6  7EX',
#  'y S9 1LH',
#  'CW 15NG',
#  'd S3 8AG',
#  'ersfield',
#  'ampshire',
#  'ordshire',
#  'LS27 OJA',
#  'd S9 1TR',
#  'heshire',
#  'unthorpe']

# %%
# Out:
# ['SO41 8DF',
#  'PO30 2PD',
#  'PO18 0NB',
#  'EX6 7XD',
#  'BA12 0LT',
#  'BH21 3QZ',
#  'BA2 8PU',
#  'WS9 9PE',
#  'WS9 0NF',
#  'LE9 3LE',
#  'DN10 6BP',
#  'WS14 0BD',
#  'TF1 5RY',
#  'WA3 7BW',
#  'WN8 7ND',
#  'SR6 7NG',
#  'DH5 8AJ',
#  'BD13 5DE',
#  'LS24 9LY',
#  'DL17 9EB',
#  'RM18 8PH',
#  'LN4 2JA',
#  'NN16 9UX',
#  'NN14 4NJ',
#  'Dn21 4JH',
#  'NN7 4EJ',
#  'NN6 8AA',
#  'LE17 6JH',
#  'PE9 3BZ',
#  'MK17 8BU',
#  'CB6 2AY',
#  'MK19 1RN',
#  'CB11 3SL',
#  'MK17 8BU',
#  'LU7 4RU',
#  'MK17 8BU',
#  'HP5 1UW',
#  'edbridge',
#  'ow Essex',
#  'RM13 9EW',
#  'SG9 0BU',
#  'UB7 0JG',
#  'AL4 0PG',
#  'EN11 8LS',
#  'r Surrey',
#  'SL2 3SD',
#  'RH3 7HB',
#  'SN7 8HE',
#  'OX10 6PJ',
#  'SL7 3SB',
#  'RG16 9DR',
#  'WF6 2JD',
#  'CB6 2PZ',
#  'CB8 7QX',
#  'LA15 8BG',
#  'WN8 0QE',
#  'HU15 2BE',
#  'SO51 0NU',
#  'HX4 0DY',
#  'SL3 0LP',
#  'B78 3DH',
#  'OX5 3EL',
#  'NN17 4AP',
#  'RM13 9GF',
#  'DN14 0RL',
#  'LU7 0AP',
#  'DH8 9HQ',
#  'TQ4 7PD',
#  'RG30 3XA',
#  'HR8 1PB',
#  'TW17 0NF',
#  'MK18 4AJ',
#  'CV33 9QJ',
#  'B61 0RF',
#  'SG17 5PJ',
#  'CB6 2AY',
#  'CM9 6TJ',
#  'DY6 8WT',
#  'DN9 3AN',
#  'WV10 7LL',
#  'NN14 4DT',
#  'PR25 4UB',
#  'DN14 0RD',
#  'RM6 6RB',
#  'DY13 9JP',
#  'ME3 0AW',
#  'DH6 1LA',
#  'BH24 3PL',
#  'W 18 4JX',
#  'DT5 1HY',
#  'S81 8BD',
#  'BS40 9UP',
#  'EX39 4LR',
#  'CV8 3BN',
#  'DY6 0AS',
#  'RG26 5HW',
#  'DT2 8DY',
#  'EX5 1EW',
#  'TW19 7XT',
#  'EX5 1SB',
#  'EX2 8XX',
#  'DE74 2RG',
#  'DE6 3ET',
#  'TA21 0LT',
#  'SY5 7EE',
#  'WS9 0NS',
#  'S45 9NE',
#  'S75 4AD',
#  'DA9 9DT',
#  'YO61 1SN',
#  'B97 6RG',
#  'TQ9 7QQ',
#  'YO41 1EP',
#  'NR13 3ST',
#  'DE6 3QU',
#  'LE17 4LT',
#  'ME19 5LJ',
#  'GU29 0ER',
#  'WF4 1QH',
#  'PE29 2EJ',
#  'TW20 8SS',
#  'CT3 1NR',
#  'IP6 9QJ',
#  'GL12 8LF',
#  'GL56 0SL',
#  'ME7 2XH',
#  'GU10 2LP',
#  'TW17 0NF',
#  'SL9 0QY',
#  'PE6 9PT',
#  'YO11 3UD',
#  'PE9 3QA',
#  'DL10 6NF',
#  'SL3 6LX',
#  'BR8 7DP',
#  'HD4 7AB',
#  'Rutland',
#  'HU10 6DP',
#  nan,
#  'SO31 1BL',
#  'RH8 0QW',
#  'B78 2BB',
#  'BH23 8EA',
#  'CO7 9JZ',
#  'SK2 5EU',
#  'GL7 4NJ',
#  'ME16 9NT',
#  'ST4 2RR',
#  'CT4 7LD',
#  'SS17 0PY',
#  'PO30 0NS',
#  'DH6 5NN',
#  'NN12 7NX',
#  'OX11 0ST',
#  'HD8 8UF',
#  'DE73 7HA',
#  'S72 7BG',
#  'PO36 0NS',
#  'DE13 7DL',
#  'YO41 4DB',
#  'CM3 3PR',
#  'NG24 1DL',
#  'SL0 0NE',
#  'NG19 8DP',
#  'B46 1JU',
#  'IP6 8RA',
#  'DL10 6AA',
#  'MK44 3PG',
#  'KT15 3LA',
#  'zard LU7',
#  'OX13 5QU',
#  'ME13 7TS',
#  'PE32 1SW',
#  'S66 7RD',
#  'SS17 0PJ',
#  'BA11 3PH',
#  'NG34 8RL',
#  'HU20 3UP',
#  'TN12 5HL',
#  'CA14 5AE',
#  'IP10 0BL',
#  'WD3 4LY',
#  'TN15 8HJ',
#  'GU10 1PG',
#  'TW17 0NF',
#  'TQ12 5LB',
#  nan,
#  'SG13 8LF',
#  'TN15 8DN',
#  'IP7 5RW',
#  'EX23 9LE',
#  'PL26 7DS',
#  'PO9 1NN',
#  'TW19 5AW',
#  'yldesley',
#  'nemouth',
#  'LS16 9JN',
#  'CB21 4HH',
#  'CO5 0QQ',
#  'YO7 3RB',
#  'DT5 1DB',
#  'PL12 6PJ',
#  'LU7 9LD',
#  'SP5 2QE',
#  'CV10 7PH',
#  'CM6 2SN',
#  'UB9 5DL',
#  'BL6 6RX',
#  'OX13 5DW',
#  'IP30 9RS',
#  'L35 1QZ',
#  'SL3 9PA',
#  'MK41 0JF',
#  'CB2 5RG',
#  'RH12 3DH',
#  'CW10 9JQ',
#  'CV10 0JQ',
#  'YO61 1TU',
#  'DE11 8HA',
#  'NE21 4SP',
#  'BD16 1TU',
#  'LS15 9AD',
#  'ST10 3EQ',
#  'SN5 9HG',
#  'YO2 3RR',
#  'SO50 7EA',
#  'LE17 6AA',
#  'PR4 0XE',
#  'GL2 7PU',
#  'CB5 9PG',
#  'DE2 8WE',
#  'TA6 4TF',
#  'Sn11 8TR',
#  'TN14 5BS',
#  'DN6  7EX',
#  'BB5 5EN',
#  'FY7 8TW',
#  'MK17 0AB',
#  'CA11 0JB',
#  'CA6 4BJ',
#  'LA14 4QH',
#  'NR34 0BL',
#  'MK18 4AJ',
#  'WS11 3EQ',
#  'PE6 7TH',
#  'WA7 4QF',
#  'y S9 1LH',
#  'BS16 9NN',
#  'WA5 2UT',
#  'ST5 6DH',
#  'DN22 0ET',
#  'S66 9AB',
#  'M27 8LN',
#  'WA4 6YZ',
#  'CW 15NG',
#  'BL9 8QZ',
#  'MK18 2HF',
#  'DN38 6AE',
#  'BD23 3LA',
#  'BS13 8AF',
#  'B65 9BT',
#  'S43 3TP',
#  'CV23 9HH',
#  'GL52 4DG',
#  'BH24 3QE',
#  'SN11 8RE',
#  'WV15 5HG',
#  'BH21 3RZ',
#  'SN5 9HG',
#  'OX15 6NL',
#  'TF2 9PB',
#  'SL3 8AB',
#  'DH4 5AU',
#  'RH1 4ER',
#  'BL9 8QZ',
#  'TF6 5AR',
#  'LS25 4DW',
#  'DN16 6UR',
#  'DN15 8QZ',
#  'GU5 9BW',
#  'NN8 1RN',
#  'PR6 7DT',
#  'WA9 4QQ',
#  'TS2 1UE',
#  'TS2 1UE',
#  'NG33 5QT',
#  'PE9 3SX',
#  'CB2 5RQ',
#  'DN6 8LX',
#  'CW1 4RQ',
#  'DA2 8EB',
#  'DN18 6JL',
#  'CH2 4JP',
#  'TS6 6UG',
#  'PL14 3QD',
#  'RH1 4ER',
#  'WS9 8TB',
#  'TS6 6UG',
#  'PE1 3TD',
#  'MK43 0TN',
#  'SS17 0RN',
#  'PE24 5AD',
#  'DN7 4JT',
#  'NG5 8PU',
#  'NG22 8UA',
#  'NR9 5TD',
#  'NR34 8AR',
#  'IP6 0NW',
#  'NN17 3JG',
#  'B76 9DP',
#  'MK43 9LY',
#  'CB4 6DG',
#  'PE15 8QN',
#  'ST15 0QF',
#  'B77 1LT',
#  'SG15 6RP',
#  'EX38 7JA',
#  'OX14 4PW',
#  'TQ12 3GP',
#  'SP5 2PU',
#  'OX29 5BJ',
#  'RG5 4UE',
#  'DY6 7YS',
#  'OX27 7PH',
#  'WA3 6BY',
#  'WN1 2XJ',
#  'CA14 4JP',
#  'BL2 4LT',
#  'PR7 6TF',
#  'RH12 4QD',
#  'BN5 9XH',
#  'CV8 3BN',
#  'ST15 0GN',
#  'SG13 8LF',
#  'RG18 9XZ',
#  'LE67 9RH',
#  'CV7 7HF',
#  'WS11 3EQ',
#  'd S3 8AG',
#  'S44 5HS',
#  'WF8 3JX',
#  'SK22 1BY',
#  'DN15 9AP',
#  'SG5 3RT',
#  'DH4 6QQ',
#  'TS25 1NS',
#  'HG5 0SD',
#  'M29 7JZ',
#  'CB6 3RQ',
#  'IP26 4DL',
#  'PE17 3HJ',
#  'IP10 0HT',
#  'DN15 0BD',
#  'LN6 9BT',
#  'LN6 3QZ',
#  'NG23 5JZ',
#  'YO8 8PQ',
#  'd S9 1TR',
#  'CV23 8XF',
#  'YO25 8SA',
#  'DN6 8DE',
#  'BH20 7PB',
#  'WA11 0RN',
#  'TN38 8AY',
#  'SN26 4DD',
#  'HU15 2RF',
#  'RG10 9YB',
#  'NN14 1RS',
#  'PO22 9PL',
#  'SO51 6GA',
#  'YO17 8JA',
#  'NE63 9XS',
#  'CA10 1XU',
#  'CV47 9RA',
#  'SG12 0ES',
#  'NG23 5JZ',
#  'WN8 8BW',
#  'OX14 3YP',
#  'B14 6LX',
#  'S81 0TT',
#  'CO3 5NN',
#  'SE28 0AB',
#  'RM13 9DA',
#  'TS25 2BS',
#  'SS16 4UH',
#  'SN4 9QT',
#  'NE63 9YH',
#  'PE18 8EJ',
#  'CA14 4JH',
#  'CW10 0HQ',
#  'BL0 0DD',
#  'RM18 8UJ',
#  'NR24 2RS',
#  'NE9 7XW',
#  'DE72 2SP',
#  'PE32 1SW',
#  'WS15 1PR',
#  'FY4 5JX',
#  'BS35 1RQ',
#  'PE32 1SW',
#  'BB7 4QF',
#  'BB11 3RL',
#  'DY10 4JA',
#  'WA3 6EN',
#  'LS27 OJA',
#  'SS3 0LL',
#  'WF12 9EA',
#  'NG11 0EE',
#  'HD2 1FF',
#  'WF11 0AH',
#  'YO16 4UU',
#  'TF8 7BL',
#  'DH6 4RT',
#  'BS11 8HT',
#  'TS16 0PS',
#  'CM22 6DJ',
#  'TR16 5HU',
#  'RG2 0RR',
#  'CB6 2AY',
#  'WS9 9AH',
#  'UB7 0AE',
#  'GL2 5JA',
#  'S18 2XU',
#  'CV33 9PP',
#  'DN22 8RB',
#  'B77 1LT',
#  'RM16 5TZ',
#  'SN5 4HG',
#  'LN5 0QF',
#  'NN17 3JG',
#  'CM1 4LT',
#  'unthorpe',
#  'LN10 6YN',
#  'LN11 9QP',
#  'LE14 3RE',
#  'NN14 4HY',
#  'CM22 6HT',
#  'DN40 1QR',
#  'CO7 7RU',
#  'IP8 4DE',
#  'TA11 6PZ',
#  'DN16 1BP',
#  'DN15 9AP',
#  'DA10 0LL',
#  'PE8 6NL',
#  'SY12 0HY',
#  'ersfield',
#  'TS10 5QW',
#  'EX15 3EP',
#  'OX20 1HR',
#  'PE18 9UH',
#  'WF11 9ED',
#  'GL52 4RT',
#  'GU10 1PB',
#  'SN11 8TJ',
#  'IP9 2NY',
#  'SN4 7SB',
#  'YO18 7JA',
#  'PE8 6XX',
#  'DL5 6NB',
#  'LS25 6BJ',
#  'PO30 2PD',
#  'WF11 0BB',
#  'BA7 7NR',
#  'OL4 3SA',
#  'SK11 9QP',
#  'DY3 4DA',
#  'DN22 0ET',
#  'PL14 4NP',
#  'B61 0QT',
#  'CR0 4TD',
#  'LN7 6SR',
#  'YO43 4ED',
#  'heshire',
#  'ME3 8RN',
#  'WF6 2JA',
#  'PE28 2TX',
#  'HP9 1XD',
#  'ME12 3AJ',
#  'NE21 4SX',
#  'PE32 1SW',
#  'S60 1DW',
#  'BD23 6AD',
#  'PE21 7AA',
#  'CT2 0PR',
#  'SL9 8TU',
#  'CW9 7TD',
#  'DN21 1AF',
#  'DN22 8BL',
#  'GL52 7RT',
#  'NE23 7DY',
#  'BH20 7PA',
#  'TR10 9DU',
#  'DY10 4HB',
#  'TS23 4HS',
#  'ME1 3RQ',
#  'WR10 2PW',
#  'KT15 3LA',
#  'DT5 1DB',
#  'GU5 9BW',
#  'NE63 9YH',
#  'NR34 0BL',
#  'WS9 0NF',
#  'OX15 6NL',
#  'SL3 6LX',
#  nan,
#  'HG5 0SD',
#  'YO61 1TU',
#  'GU10 5EL',
#  'SG9 0BU',
#  'SK22 1BY',
#  'OX27 7PH',
#  'SG15 6RP',
#  'TN12 5HL',
#  'WA4 6YZ',
#  'YO7 3RB',
#  'NR9 5TD',
#  'nemouth',
#  'DL5 6NB',
#  'PR7 6TF',
#  'DN9 3AN',
#  'S75 4AD',
#  'SS3 0LL',
#  'YO8 8PQ',
#  'WF8 3JX',
#  'WV15 5HG',
#  'CB2 5RG',
#  'CB2 5RQ',
#  'DL10 6NF',
#  'BH21 3RZ',
#  'CR0 4TD',
#  'PO9 1NN',
#  'SL2 3SD',
#  'CO3 5NN',
#  'LA14 4QH',
#  'RH3 7HB',
#  'NG22 8UA',
#  'DL17 9EB',
#  'PE32 1SW',
#  'PE32 1SW',
#  'PE32 1SW',
#  'LS16 9JN',
#  'NE21 4SX',
#  'BH24 3PL',
#  'MK17 0AB',
#  'BH24 3QE',
#  'DN22 8BL',
#  'DN7 4JT',
#  'TN15 8HJ',
#  'TN15 8DN',
#  'NG24 1DL',
#  'CW10 9JQ',
#  'PE21 7AA',
#  'NN6 8AA',
#  'BR8 7DP',
#  'PO18 0NB',
#  'LE67 9RH',
#  'HD2 1FF',
#  'IP8 4DE',
#  'CT3 1NR',
#  'WS9 0NS',
#  'NG34 8RL',
#  'SP5 2QE',
#  'LU7 4RU',
#  'CO7 0SB',
#  'LS27 OJA',
#  'CM1 4LT',
#  'DT5 1HY',
#  'EX15 3EP',
#  'MK43 0TN',
#  'RH12 4QD',
#  'WF11 9ED',
#  'CV8 3BN',
#  'PE18 9UH',
#  'SG13 8LF',
#  'RG2 0RR',
#  'SG17 5PJ',
#  'SN11 8TJ',
#  'MK18 2HF',
#  'DN38 6AE',
#  'TF6 5AR',
#  'NR13 3ST',
#  'S72 7BG',
#  'S81 0TT',
#  'YO16 4UU',
#  'YO18 7JA',
#  'CM3 3PR',
#  'SN26 4DD',
#  'CT4 7LD',
#  'OX11 0ST',
#  'BA12 0LT',
#  'PR6 7DT',
#  'TS10 5QW',
#  'M27 8LN',
#  'PR4 0XE',
#  'HX4 0DY',
#  'HD8 8UF',
#  'TS16 0PS',
#  'TW20 8SS',
#  'B46 1JU',
#  'PE9 3QA',
#  'SL3 8AB',
#  'NG33 5QT',
#  'DN15 8QZ',
#  'PL14 4NP',
#  'LS25 6BJ',
#  'RG16 9DR',
#  'NN17 3JG',
#  'LE17 6AA',
#  'DN22 0ET',
#  'PE29 2EJ',
#  'TS23 4HS',
#  'WS14 0BD',
#  'NN14 4HY',
#  'DH6 1LA',
#  'DN6 8DE',
#  'L35 1QZ',
#  'unthorpe',
#  'GL56 0SL',
#  'ow Essex',
#  'AL4 0HL',
#  'MK41 0JF',
#  'SK11 9QP',
#  'DN22 8RB',
#  'IP6 8RA',
#  'WF11 0AH',
#  'EX38 7JA',
#  'BB11 3RL',
#  'UB9 5DL',
#  'BA7 7NR',
#  'CA14 4JP',
#  'OX29 5BJ',
#  'PE1 3TD',
#  'NG5 8PU',
#  'SY5 7EE',
#  'CW1 4RQ',
#  'PE8 6XX',
#  'RM18 8PH',
#  'PE32 1SW',
#  'NR24 2RS',
#  'B65 9BT',
#  'DN14 0RL',
#  'S45 9NE',
#  'NE63 9XS',
#  'LE67 1ET',
#  'CM22 6DJ',
#  'DY6 0AS',
#  'S44 5HS',
#  'OX10 6PJ',
#  'PE6 7TH',
#  'SO50 7EA',
#  'edbridge',
#  'IP26 4DL',
#  'ST4 2RR',
#  'WA5 2UT',
#  'DH5 8AJ',
#  'MK18 4AJ',
#  'MK18 4AJ',
#  'BL0 0DD',
#  'YO11 3UD',
#  'CA11 0JB',
#  'IP9 2NY',
#  'HR8 1PB',
#  'IP10 0HT',
#  'GL2 7PU',
#  'DN21 1AF',
#  'WF11 0BB',
#  'YO43 4ED',
#  'SL9 8TU',
#  'HU15 2RF',
#  'CV8 3BN',
#  'PE18 8EJ',
#  'LA15 8BG',
#  'CH2 4JP',
#  'PE9 3SX',
#  'TF2 9PB',
#  'WD3 4LY',
#  'TN14 5BS',
#  'EX5 1EW',
#  'CV10 7PH',
#  'CB6 3RQ',
#  'BD13 5DE',
#  'ME13 7TS',
#  'WN8 0QE',
#  'YO2 3RR',
#  'NN7 4EJ',
#  'UB7 0AE',
#  'LN4 2JA',
#  'S81 8BD',
#  'DY10 4HB',
#  'BL2 4LT',
#  'DN6  7EX',
#  'TQ12 3GP',
#  'GL2 5JA',
#  'BH21 3QZ',
#  'W 18 4JX',
#  'DN14 0RD',
#  'RG18 9XZ',
#  'ME16 9NT',
#  'CA6 4BJ',
#  'WS9 9AH',
#  'OL4 3SA',
#  'CM6 2SN',
#  'WR10 2PW',
#  'EX5 1SB',
#  'CW10 0HQ',
#  'DY6 7YS',
#  'SL6 6NL',
#  'EN11 8LS',
#  'CW9 7TD',
#  'DH8 9HQ',
#  'EX39 4LR',
#  'S66 7RD',
#  'y S9 1LH',
#  'BH23 8EA',
#  'TW17 0NF',
#  'TW17 0NF',
#  'GU10 1PG',
#  'SL3 0LP',
#  'BN5 9XH',
#  'DH4 5AU',
#  'DE6 3ET',
#  'LE9 3LE',
#  'SO51 0NU',
#  'RG5 4UE',
#  'LE17 6JH',
#  'TW19 5AW',
#  'TS6 6UG',
#  'TS6 6UG',
#  'DN40 1QR',
#  'CO5 0QQ',
#  'TF8 7BL',
#  'FY7 8TW',
#  'DH6 4RT',
#  'CV10 0JQ',
#  'GL7 4NJ',
#  'EX6 7XD',
#  'CB8 7QX',
#  'CB8 7QX',
#  'LN11 9QP',
#  'DY6 8WT',
#  'CV23 8XF',
#  'heshire',
#  'B77 1LT',
#  'GU35 9NQ',
#  'SL3 9PA',
#  'BS11 8HT',
#  'LN10 6YN',
#  'CA10 1XU',
#  'Dn21 4JH',
#  'YO17 8JA',
#  'PO36 0NS',
#  'TW17 0NF',
#  'HP5 1UW',
#  'PE6 0QL',
#  'ersfield',
#  'IP30 9RS',
#  'IP7 5RW',
#  'LN5 0QF',
#  'PL14 3QD',
#  'PO22 9PL',
#  'CA14 4JH',
#  'BA11 3PH',
#  'SS17 0PY',
#  'CV23 9HH',
#  'SL7 3SB',
#  'HU10 6DP',
#  'HU10 6DP',
#  'DE74 2RG',
#  'MK17 8BU',
#  'NN16 9UX',
#  'TS25 1NS',
#  'WA9 4QQ',
#  'SN11 8RE',
#  'SO41 8DF',
#  'PO30 0NS',
#  'r Surrey',
#  'ME7 2XH',
#  'BS40 9UP',
#  'PR25 4UB',
#  'WA11 0RN',
#  'PO30 2PD',
#  'RG26 5HW',
#  'PE6 9PT',
#  'PE15 8QN',
#  'ME1 3RQ',
#  'DH4 6QQ',
#  'RM6 6RB',
#  'SR6 7NG',
#  'CO7 7RU',
#  'IP6 0NW',
#  'CW 15NG',
#  'HP5 1UW',
#  'ST15 0GN',
#  'ST15 0QF',
#  'CB6 2PZ',
#  'CB6 2AY',
#  'NE43 7NS',
#  'PE24 5AD',
#  'B78 2BB',
#  'YO25 8SA',
#  'CB4 6DG',
#  'B76 9DP',
#  'yldesley',
#  'SS17 0RN',
#  'YO61 1SN',
#  'CV7 7JT',
#  'LN7 6SR',
#  'TF1 5RY',
#  'DE11 8HA',
#  'DN16 6UR',
#  'SG5 3RT',
#  'LN6 3QZ',
#  'ME12 3AJ',
#  'WF4 1QH',
#  'DY3 4DA',
#  'DY3 4DA',
#  'RM16 5TZ',
#  'MK44 3PG',
#  'SK2 5EU',
#  'DT2 8DY',
#  'DH6 5NN',
#  'BS35 1RQ',
#  'S60 1DW',
#  'RH8 0QW',
#  'CV7 7HF',
#  'SN4 7SB',
#  'SL0 0NE',
#  'SN5 4HG',
#  'SN5 9HG',
#  'd S3 8AG',
#  'MK19 1RN',
#  'NE21 4SP',
#  'TN38 8AY',
#  'LS25 4DW',
#  'GU29 0ER',
#  'ME3 0AW',
#  'SG14 2NL',
#  'BL6 6RX',
#  'BL9 8QZ',
#  'BL9 8QZ',
#  'B61 0RF',
#  'DA2 8EB',
#  'SS16 4UH',
#  'WS11 3EQ',
#  'WS11 3EQ',
#  'TS2 1UE',
#  'TS2 1UE',
#  'SP5 2PU',
#  'DE2 8WE',
#  'NN17 4AP',
#  'SN5 9HG',
#  'NN12 7NX',
#  'OX14 3YP',
#  'SS17 0PJ',
#  'RM13 9DA',
#  'DN22 0ET',
#  'WA7 4QF',
#  'NG11 0EE',
#  'LU7 9LD',
#  'RG30 3XA',
#  'NN14 4NJ',
#  'RH1 4ER',
#  'RH1 4ER',
#  'BB7 4QF',
#  'NN14 4DT',
#  'HU20 3UP',
#  'WA3 6BY',
#  'WA3 6EN',
#  nan,
#  'PL12 6PJ',
#  'SO31 1BL',
#  'WN8 7ND',
#  'DN15 0BD',
#  'CM9 6TJ',
#  'WF6 2JD',
#  'RH12 3DH',
#  'WS15 1PR',
#  'GU10 1PB',
#  'NN14 1RS',
#  'BD16 1TU',
#  'CM2 7RL',
#  'PR7 4DL',
#  'Sn11 8TR',
#  'B61 0QT',
#  'WV10 7LL',
#  'TS25 2BS',
#  'NE23 7DY',
#  'DN10 6BP',
#  'ME3 8RN',
#  'DE72 2SP',
#  'zard LU7',
#  'CT2 0PR',
#  'SN7 8HE',
#  'OX5 3EL',
#  'WS9 9PE',
#  'BS16 9NN',
#  'IP6 9QJ',
#  'NN8 1RN',
#  'UB7 0JG',
#  'DN6 8LX',
#  'LS15 9AD',
#  'BD23 6AD',
#  'OX20 1HR',
#  'DE6 3QU',
#  'LE17 4LT',
#  'LS24 9LY',
#  'PE17 3HJ',
#  'DN18 6JL',
#  'RM13 9EW',
#  'DA10 0LL',
#  'CV47 9RA',
#  'SG13 8LF',
#  'PE9 3BZ',
#  'B14 6LX',
#  'WA3 7BW',
#  'NR10 3PR',
#  'RM13 9GF',
#  'HP9 1XD',
#  'NE9 7XW',
#  'SO51 6GA',
#  'PO30 2PD',
#  'TW19 7XT',
#  'NG23 5JZ',
#  'RG10 9YB',
#  'S43 3TP',
#  'MK43 9LY',
#  'GU10 2LP',
#  'LU7 0AP',
#  'DA9 9DT',
#  'SN4 9QT',
#  'DY13 9JP',
#  'OX14 4PW',
#  'OX14 4PW',
#  'DE73 7HA',
#  'HU15 2BE',
#  'DL10 6AA',
#  'BD23 3LA',
#  'BH20 7PA',
#  'PE8 6NL',
#  'PE8 6NL',
#  'WF12 9EA',
#  'S66 9AB',
#  'RM18 8UJ',
#  'd S9 1TR',
#  'EX23 9LE',
#  'CV33 9QJ',
#  'PL26 7DS',
#  'BH20 7PB',
#  'SE28 0AB',
#  'EX2 8XX',
#  'OX13 5QU',
#  'AL4 0PG',
#  'CV33 9PP',
#  'CM22 6HT',
#  'TR16 5HU',
#  'OX13 5DW',
#  'NG19 8DP',
#  'WS9 8TB',
#  'IP10 0BL',
#  'ST5 6DH',
#  'TA6 4TF',
#  'NR34 8AR',
#  'PE28 2TX',
#  'DY10 4JA',
#  'SL9 0QY',
#  'CB5 9PG',
#  'B97 6RG',
#  'WF6 2JA',
#  'LE14 3RE',
#  'NN17 3JG',
#  'HD4 7AB',
#  'FY4 5JX',
#  'SG12 0ES',
#  'BB5 5EN',
#  'LN6 9BT',
#  'TA11 6PZ',
#  'TA21 0LT',
#  'M29 7JZ',
#  'YO41 1EP',
#  'DE13 7DL',
#  'WN8 8BW',
#  'MK17 8BU',
#  'MK17 8BU',
#  'GL12 8LF',
#  'CB11 3SL',
#  'YO41 4DB',
#  'CB21 4HH',
#  'S18 2XU',
#  'BA2 8PU',
#  'PE6 0QN',
#  'B77 1LT',
#  'GL52 4DG',
#  'GL52 4RT',
#  'GL52 7RT',
#  'DN15 9AP',
#  'DN15 9AP',
#  'CB6 2AY',
#  'CB6 2AY',
#  'CO7 9JZ',
#  ...]

# %%
df[~(df["remaining_capacity"].isin(["Closed", 0])) & (df["year"]==2024)]
# Out:
#            epr legacy_permit                           operator_name  \
# 4721  AB3009HS        400345  Sewells Reservoir Construction Limited
# 4722  AB3100UQ         40059              J P E ( Holdings ) Limited
# 4723  AB3105HD        400391                  Ingrebourne Valley Ltd
# 4725  AB3305MU        400532           Armstrongs Aggregates Limited
# 4727  AB3402KQ        400588           Hills Quarry Products Limited
# ...        ...           ...                                     ...
# 5254  ZP3232SF      ZP3232SF                Biffa Waste Services Ltd
# 5256  ZP3497EW        102911                   Allen Newport Limited
# 5258  ZP3606BG      ZP3606BG                   British Steel Limited
# 5260  ZP3835JD        406424  Escrick Environmental Services Limited
# 5261  ZP3933LD      ZP3933LD           Severn Waste Services Limited
#
#                        facility_name  \
# 4721  Highwood Quarry Inert Landfill
# 4722                Shire Oak Quarry
# 4723                Denham Park Farm
# 4725               Pilkington Quarry
# 4727                   Upwood Quarry
# ...                              ...
# 5254        Hartlebury Landfill Site
# 5256                   Marston's Pit
# 5258           Crosby North Landfill
# 5260      Escrick Soil Landfill Site
# 5261          Hill and Moor Landfill
#
#                                        facility_address  \
# 4721  Highwood Quarry,  Little Easton, Great Dunmow,...
# 4722  Shire Oak Quarry,  Chester Road, Shire Oak, Wa...
# 4723  Denham Park Farm,  Denham Green, Buckinghamshi...
# 4725  Pilkington Quarry,  Makinson Lane, Horwich, Bo...
# 4727  Upwood Quarry,  Besselsleigh, Abingdon, Oxford...
# ...                                                 ...
# 5254                Whitlenge Lane, Hartlebury DY10 4HB
# 5256  Marstons Pit Cavenham Road Tuddenham Bury St. ...
# 5258                              Daws Lane, Scunthorpe
# 5260  Escrick Environmental Services Ltd,  The Old B...
# 5261         Throckmorton, Pershore, Worcester WR10 2PW
#
#                         ea_area                   region          sub_region  \
# 4721     Herts and North London          East of England               Essex
# 4722              West Midlands           West Midlands        Staffordshire
# 4723     Herts and North London              South East      Buckinghamshire
# 4725  Gtr Mancs Mersey and Ches               North West  Greater Manchester
# 4727                     Thames              South East          Oxfordshire
# ...                         ...                      ...                 ...
# 5254              West Midlands           West Midlands       Worcestershire
# 5256                East Anglia          East of England             Suffolk
# 5258              East Midlands  Yorkshire & the Humber    Former Humberside
# 5260                  Yorkshire  Yorkshire & the Humber      North Yorkshire
# 5261              West Midlands           West Midlands       Worcestershire
#
#           local_authority                                     site_type  \
# 4721           Uttlesford                          L05 - Inert Landfill
# 4722            Lichfield                          L05 - Inert Landfill
# 4723      Buckinghamshire                          L05 - Inert Landfill
# 4725               Bolton                          L05 - Inert Landfill
# 4727  Vale of White Horse                          L05 - Inert Landfill
# ...                   ...                                           ...
# 5254             Wychavon  L02 - Non Hazardous Landfill With SNRHW cell
# 5256         West Suffolk                          L05 - Inert Landfill
# 5258   North Lincolnshire                           L04 - Non Hazardous
# 5260      North Yorkshire                          L05 - Inert Landfill
# 5261             Wychavon                           L04 - Non Hazardous
#
#      remaining_capacity  year
# 4721             724735  2024
# 4722             726575  2024
# 4723             130854  2024
# 4725             648543  2024
# 4727             210746  2024
# ...                 ...   ...
# 5254             475913  2024
# 5256            2641287  2024
# 5258            1641301  2024
# 5260             428521  2024
# 5261            1455487  2024
#
# [286 rows x 12 columns]
